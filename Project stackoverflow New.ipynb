# %% [markdown]
# # ANALYZING DEVELOPERS ON STACKOVERFLOW(SO) IN 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None

# %%
data=pd.read_csv('survey_results_public.csv')
schema=pd.read_csv('survey_results_schema.csv')
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
schema.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
print(data.shape)
print(schema.shape)
# Out:
# (88883, 85)
# (85, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
data[data['MainBranch']=='I am a student who is learning to code'].head()
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 0            1  I am a student who is learning to code      Yes
# 1            2  I am a student who is learning to code       No
# 11          12  I am a student who is learning to code       No
# 14          15  I am a student who is learning to code      Yes
# 30          31  I am a student who is learning to code       No
#
#                 OpenSourcer  \
# 0                     Never
# 1   Less than once per year
# 11                    Never
# 14                    Never
# 30                    Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 1   The quality of OSS and closed source software ...
# 11  OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
# 30                                                NaN
#
#                                 Employment                 Country  \
# ...

# %% [markdown]
# ##### Most of the missing data comes from students who are learning to code. Some of the questions were about issues that require workplace participation, sicnce they dont have, they didnt answer

# %%
data['UndergradMajor']=data['UndergradMajor'].fillna('No undergrad major')

# %%
data.isnull().sum()
# Out:
# Respondent          0
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 85, dtype: int64

# %%
data['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   65679
# I am a student who is learning to code                                           10189
# I am not primarily a developer, but I write code sometimes as part of my work     7539
# I code primarily as a hobby                                                       3340
# I used to be a developer by profession, but no longer am                          1584
# Name: MainBranch, dtype: int64

# %%
data['MainBranch']=data['MainBranch'].fillna('Not Sure What i am')

# %%
data['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   65679
# I am a student who is learning to code                                           10189
# I am not primarily a developer, but I write code sometimes as part of my work     7539
# I code primarily as a hobby                                                       3340
# I used to be a developer by profession, but no longer am                          1584
# Not Sure What i am                                                                 552
# Name: MainBranch, dtype: int64

# %%
data.isnull().sum()
# Out:
# Respondent          0
# MainBranch          0
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 85, dtype: int64

# %%
data['OpenSource']=data['OpenSource'].fillna('not sure about open source')

# %%
data['OpenSource'].value_counts()
# Out:
# The quality of OSS and closed source software is about the same                    41527
# OSS is, on average, of HIGHER quality than proprietary / closed source software    36556
# OSS is, on average, of LOWER quality than proprietary / closed source software      8759
# not sure about open source                                                          2041
# Name: OpenSource, dtype: int64

# %%
data['Employment'].value_counts()
# Out:
# Employed full-time                                      64440
# Independent contractor, freelancer, or self-employed     8511
# Not employed, but looking for work                       5600
# Employed part-time                                       4469
# Not employed, and not looking for work                   3803
# Retired                                                   358
# Name: Employment, dtype: int64

# %%
data['Employment']=data['Employment'].fillna('Cannot say')

# %%
data['Employment'].value_counts()
# Out:
# Employed full-time                                      64440
# Independent contractor, freelancer, or self-employed     8511
# Not employed, but looking for work                       5600
# Employed part-time                                       4469
# Not employed, and not looking for work                   3803
# Cannot say                                               1702
# Retired                                                   358
# Name: Employment, dtype: int64

# %%
data['Country']=data['Country'].fillna('Country isnt listed')

# %%
data['Student']=data['Student'].fillna('I prefer not to say')

# %%
data['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: EdLevel, dtype: int64

# %%
data['EdLevel']=data['EdLevel'].fillna('Cannot Say')

# %%
data['EduOther']=data['EduOther'].fillna('Didnt take other educational route')

# %%
data['OrgSize'].value_counts()
# Out:
# 20 to 99 employees                                    15199
# 100 to 499 employees                                  12834
# 10,000 or more employees                              10147
# 1,000 to 4,999 employees                               7520
# 2-9 employees                                          7393
# 10 to 19 employees                                     6768
# 500 to 999 employees                                   4575
# Just me - I am a freelancer, sole proprietor, etc.     4370
# 5,000 to 9,999 employees                               2985
# Name: OrgSize, dtype: int64

# %%
data['OrgSize']=data['OrgSize'].fillna('Dont belong to any organization')

# %%
data['DevType']=data['DevType'].fillna('None of these')

# %%
data=data.dropna(subset=['YearsCode','Age1stCode','LanguageWorkedWith','SurveyLength','SurveyEase','EntTeams'])

# %%
data['YearsCodePro']=data['YearsCodePro'].fillna('Not a Pro')

# %%
data['CareerSat']=data['CareerSat'].fillna('Not started career yet')

# %%
data['JobSat']=data['JobSat'].fillna('Not started Job yet')

# %%
data['MgrIdiot']=data['MgrIdiot'].fillna('Not reached there to know')
data['MgrMoney']=data['MgrMoney'].fillna('Not reached there to know')
data['MgrWant']=data['MgrWant'].fillna('Not reached there to know')

# %%
data['LastHireDate'].value_counts()
# Out:
# Less than a year ago                                    24961
# 1-2 years ago                                           20618
# More than 4 years ago                                   14089
# 3-4 years ago                                           11216
# NA - I am an independent contractor or self employed     3218
# I've never had a job                                     2791
# Name: LastHireDate, dtype: int64

# %%
data['LastHireDate']=data['LastHireDate'].fillna('Cannot Say')

# %%
data=data.drop(columns='LastInt')

# %%
data['FizzBuzz']=data['FizzBuzz'].fillna('No')

# %%
data['JobFactors']=data['JobFactors'].fillna('Cannot say')

# %%
data['ResumeUpdate']=data['ResumeUpdate'].fillna('Havent updated')

# %%
data=data.drop(columns=['CurrencySymbol','CurrencyDesc','CompTotal'])

# %%
data['CompFreq']=data['CompFreq'].fillna('Not yet compensated')

# %%
data['ConvertedComp']=data['ConvertedComp'].fillna(0)

# %%
data['WorkPlan']=data['WorkPlan'].fillna('Not started work')

# %%
data['WorkWeekHrs']=data['WorkWeekHrs'].fillna(0)

# %%
data['WorkChallenge']=data['WorkChallenge'].fillna('Not started work')

# %%
data=data.drop(columns=['CodeRevHrs','WebFrameWorkedWith','WebFrameDesireNextYear','MiscTechWorkedWith','MiscTechDesireNextYear'])

# %%
data=data.drop(columns=['UnitTests','PurchaseHow','PurchaseWhat','DatabaseDesireNextYear','BlockchainOrg',
                       'BlockchainIs','SONewContent'])

# %%
data['WorkRemote']=data['WorkRemote'].fillna('Not started work')

# %%
data['WorkLoc']=data['WorkLoc'].fillna('Not started work')

# %%
data['ImpSyn']=data['ImpSyn'].fillna('Dont know as of yet')

# %%
data['CodeRev'].value_counts()
# Out:
# Yes, because I see value in code review    47157
# No                                         16129
# Yes, because I was told to do so            5144
# Name: CodeRev, dtype: int64

# %%
data=data.drop(columns=['CodeRev'])

# %%
data['LanguageDesireNextYear'].value_counts()
# Out:
# Python                                                                1139
# HTML/CSS;JavaScript                                                    663
# HTML/CSS;JavaScript;TypeScript                                         622
# C#                                                                     571
# C#;HTML/CSS;JavaScript;SQL                                             555
#                                                                       ...
# C#;Go;HTML/CSS;JavaScript;SQL;Swift;TypeScript;WebAssembly               1
# Assembly;Bash/Shell/PowerShell;Go;Kotlin;Objective-C;Rust                1
# Dart;HTML/CSS;Java;JavaScript;Kotlin;Swift;TypeScript;WebAssembly        1
# Bash/Shell/PowerShell;Elixir;JavaScript;Python;Rust;SQL;TypeScript       1
# Bash/Shell/PowerShell;C;HTML/CSS;Objective-C;PHP;Python;SQL              1
# Name: LanguageDesireNextYear, Length: 26614, dtype: int64

# %%
data['LanguageDesireNextYear']=data['LanguageDesireNextYear'].fillna('Other')

# %%
data['DatabaseWorkedWith']=data['DatabaseWorkedWith'].fillna('None')

# %%
data['PlatformWorkedWith']=data['PlatformWorkedWith'].fillna('None')

# %%
data=data.drop(columns=['PlatformDesireNextYear'])

# %%
data['DevEnviron']=data['DevEnviron'].fillna('Other')

# %%
data['OpSys']=data['OpSys'].fillna('Other')

# %%
data['Containers']=data['Containers'].fillna('Cannot say')

# %%
data['BetterLife']=data['BetterLife'].fillna('Not sure')

# %%
data=data.drop(columns=['OffOn'])

# %%
data['SocialMedia']=data['SocialMedia'].fillna('Other')

# %%
data['Extraversion'].isnull().sum()
# Out:
# 690

# %%
data['Extraversion'].value_counts()
# Out:
# In real life (in person)    51081
# Online                      23835
# Neither                      9004
# Name: Extraversion, dtype: int64

# %%
data['Extraversion']=data['Extraversion'].fillna('Cannot say')

# %%
data['ScreenName'].value_counts()
# Out:
# Username       57163
# Login           8271
# UserID          6497
# Handle          3867
# Screen Name     1924
# Name: ScreenName, dtype: int64

# %%
data['ScreenName']=data['ScreenName'].fillna('Other')

# %%
data['SOVisit1st'].isnull().sum()
# Out:
# 3966

# %%
data['SOVisit1st'].value_counts()
# Out:
# 2010                10030
# I don't remember     9819
# 2008                 9264
# 2012                 8451
# 2011                 6497
# 2013                 6419
# 2014                 6362
# 2009                 6226
# 2015                 5592
# 2016                 4612
# 2017                 3593
# 2018                 2384
# 2019                 1395
# Name: SOVisit1st, dtype: int64

# %%
data['SOVisit1st']=data['SOVisit1st'].fillna('Cannot say')

# %%
data['SOVisitFreq'].value_counts()
# Out:
# Daily or almost daily                                 25909
# Multiple times per day                                25852
# A few times per week                                  19215
# A few times per month or weekly                       10544
# Less than once per month or monthly                    2629
# I have never visited Stack Overflow (before today)      344
# Name: SOVisitFreq, dtype: int64

# %%
data['SOVisitFreq'].isnull().sum()
# Out:
# 117

# %%
data['SOVisitTo']=data['SOVisitTo'].fillna('Other')

# %%
data['SOFindAnswer'].value_counts()
# Out:
# 1-2 times per week             23289
# 3-5 times per week             22206
# More than 10 times per week    14537
# 6-10 times per week            12465
# Less than once per week        11812
# Name: SOFindAnswer, dtype: int64

# %%
data['SOFindAnswer'].isnull().sum()
# Out:
# 301

# %%
data=data.dropna(subset=['SOFindAnswer'])

# %%
data['SOTimeSaved']=data['SOTimeSaved'].fillna('Not sure')

# %%
data=data.drop(columns=['SOHowMuchTime','SOPartFreq','ITperson'])

# %%
data['SOAccount'].value_counts()
# Out:
# Yes                          72095
# No                            7841
# Not sure / can't remember     4028
# Name: SOAccount, dtype: int64

# %%
data['SOAccount'].isnull().sum()
# Out:
# 345

# %%
data=data.dropna(subset=['SOAccount'])

# %%
data['SOJobs'].value_counts()
# Out:
# Yes                                                                                 39829
# No, I knew that Stack Overflow had a job board but have never used or visited it    30903
# No, I didn't know that Stack Overflow had a job board                               13190
# Name: SOJobs, dtype: int64

# %%
data['SOJobs'].isnull().sum()
# Out:
# 42

# %%
data=data.dropna(subset=['SOJobs'])

# %%
data=data.dropna(subset=['SOComm'])

# %%
data=data.dropna(subset=['WelcomeChange'])

# %%
data['Age'].value_counts()
# Out:
# 25.0    4442
# 27.0    4233
# 24.0    4214
# 28.0    4194
# 26.0    4159
#         ...
# 81.0       1
# 88.0       1
# 98.9       1
# 83.0       1
# 85.0       1
# Name: Age, Length: 123, dtype: int64

# %%
data['Age'].isnull().sum()
# Out:
# 6894

# %%
data=data.dropna(subset=['Age'])

# %%
data['Gender']=data['Gender'].fillna('Prefer not to say')

# %%
data['Trans']=data['Trans'].fillna('Prefer not to say')

# %%
data['Sexuality']=data['Sexuality'].fillna('Prefer not to say')

# %%
data['Ethnicity']=data['Ethnicity'].fillna('Prefer not to say')

# %%
data['Dependents']=data['Dependents'].fillna('I prefer not to answer')

# %%
data['JobSeek'].value_counts()
# Out:
# I’m not actively looking, but I am open to new opportunities    40657
# I am not interested in new job opportunities                    18554
# I am actively looking for a job                                  9929
# Name: JobSeek, dtype: int64

# %%
data['JobSeek']=data['JobSeek'].fillna('Cannot say')

# %%
data['JobSeek'].isnull().sum()
# Out:
# 0

# %%
data['SOVisitFreq'].isnull().sum()
# Out:
# 61

# %%
data['SOVisitFreq'].value_counts()
# Out:
# Multiple times per day                 23379
# Daily or almost daily                  23344
# A few times per week                   17194
# A few times per month or weekly         9170
# Less than once per month or monthly     2131
# Name: SOVisitFreq, dtype: int64

# %%
data=data.dropna(subset=['SOVisitFreq'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75218 entries, 0 to 88882
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              75218 non-null  int64
#  1   MainBranch              75218 non-null  object
#  2   Hobbyist                75218 non-null  object
#  3   OpenSourcer             75218 non-null  object
#  4   OpenSource              75218 non-null  object
#  5   Employment              75218 non-null  object
#  6   Country                 75218 non-null  object
#  7   Student                 75218 non-null  object
#  8   EdLevel                 75218 non-null  object
#  9   UndergradMajor          75218 non-null  object
#  10  EduOther                75218 non-null  object
#  11  OrgSize                 75218 non-null  object
#  12  DevType                 75218 non-null  object
#  13  YearsCode               75218 non-null  object
# ...

# %% [markdown]
# ### Whew... that was a lot of missing values, had to carefully go through to see which ones were missing on purpose or mistakes or etc, i dropped the ones i felt were mistakes and wont impact, most of them did not want to answer the 'delicate questions', like gender, ethinicity etc, and i dropped the columns that i felt werent neccesary and had a lot of missing values

# %%
sum(data.isnull().any(axis=0))
# Out:
# 0

# %%
sum(data.duplicated())
# Out:
# 0

# %% [markdown]
# ### I need to drop the columns i wouldnt use for my analysis, there are going to be a lot of columns dropped btw...

# %%
data.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                             EduOther  \
# 0  Taught yourself a new language, framework, or ...
#
#                            OrgSize        DevType YearsCode Age1stCode  \
# 0  Dont belong to any organization  None of these         4         10
#
#   YearsCodePro               CareerSat               JobSat  \
# 0    Not a Pro  Not started career yet  Not started Job yet
#
#                     MgrIdiot                   MgrMoney  \
# ...

# %%
data=data.drop(columns=['OrgSize','MgrIdiot','MgrMoney','MgrWant','ResumeUpdate','WorkChallenge','ImpSyn','PlatformWorkedWith','DevEnviron',
                  'Containers','BetterLife','ScreenName','WelcomeChange','Trans','SurveyLength','SurveyEase'])

# %%
data.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                             EduOther        DevType YearsCode  \
# 0  Taught yourself a new language, framework, or ...  None of these         4
#
#   Age1stCode YearsCodePro               CareerSat               JobSat  \
# 0         10    Not a Pro  Not started career yet  Not started Job yet
#
#       JobSeek LastHireDate FizzBuzz  JobFactors             CompFreq  \
# 0  Cannot say   Cannot Say       No  Cannot say  Not yet compensated
#
# ...

# %%
data=data.drop(columns=['Hobbyist','YearsCodePro','LastHireDate','FizzBuzz','JobFactors','WorkPlan','SOJobs','EntTeams',
                  'Sexuality','Ethnicity'])

# %%
data.head(1)
# Out:
#    Respondent                              MainBranch OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                             EduOther        DevType YearsCode  \
# 0  Taught yourself a new language, framework, or ...  None of these         4
#
#   Age1stCode               CareerSat               JobSat     JobSeek  \
# 0         10  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  ConvertedComp  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated            0.0          0.0  Not started work
#
# ...

# %%
data=data.drop(columns=['OpSys','OpenSource','LanguageDesireNextYear','SOFindAnswer','SOTimeSaved','SOAccount',
                        'Dependents','SOComm','Extraversion'])

# %%
data.shape
# Out:
# (75218, 28)

# %%
data=data.rename(columns={'ConvertedComp':'TotalComp($)','SOVisit1st':'SO1stVisit','EduOther':'OtherNondegreeEdu',
                         'MainBranch':'Profession'})

# %%
data['OpenSourcer']=data['OpenSourcer'].astype('object')

# %%
data.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                    OtherNondegreeEdu        DevType YearsCode  \
# 0  Taught yourself a new language, framework, or ...  None of these         4
#
#   Age1stCode               CareerSat               JobSat     JobSeek  \
# 0         10  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
# ...

# %%
data.dtypes
# Out:
# Respondent              int64
# Profession             object
# OpenSourcer            object
# Employment             object
# Country                object
# Student                object
# EdLevel                object
# UndergradMajor         object
# OtherNondegreeEdu      object
# DevType                object
# YearsCode              object
# Age1stCode             object
# CareerSat              object
# JobSat                 object
# JobSeek                object
# CompFreq               object
# TotalComp($)          float64
# WorkWeekHrs           float64
# WorkRemote             object
# WorkLoc                object
# LanguageWorkedWith     object
# DatabaseWorkedWith     object
# SocialMedia            object
# SO1stVisit             object
# SOVisitFreq            object
# SOVisitTo              object
# Age                   float64
# Gender                 object
# dtype: object

# %% [markdown]
# ### The neccesary columns have been renamed, the data types are of the right types, i think this is the end of the data cleaning

# %%
data.to_csv('data_clean.csv')
