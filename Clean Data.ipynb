# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None

# %%
df=pd.read_csv('data_clean.csv')
df.head()
# Out:
#    Unnamed: 0  Respondent                                         Profession  \
# 0           0           1             I am a student who is learning to code
# 1           2           3  I am not primarily a developer, but I write co...
# 2           3           4                     I am a developer by profession
# 3           4           5                     I am a developer by profession
# 4           5           6  I am not primarily a developer, but I write co...
#
#                   OpenSourcer                              Employment  \
# 0                       Never  Not employed, and not looking for work
# 1                       Never                      Employed full-time
# 2                       Never                      Employed full-time
# 3  Once a month or more often                      Employed full-time
# 4                       Never                      Employed full-time
#
#           Country Student                                   EdLevel  \
# 0  United Kingdom      No                 Primary/elementary school
# 1        Thailand      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2   United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3         Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4          Canada      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                 No undergrad major
# 1                      Web development or web design
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4                          Mathematics or statistics
#
#                                    OtherNondegreeEdu  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taught yourself a new language, framework, or ...
# 2  Taken an online course in programming or softw...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                                              DevType YearsCode Age1stCode  \
# 0                                      None of these         4         10
# 1  Designer;Developer, back-end;Developer, front-...         3         22
# 2                              Developer, full-stack         3         16
# 3  Academic researcher;Developer, desktop or ente...        16         14
# 4  Data or business analyst;Data scientist or mac...        13         15
#
#                 CareerSat                 JobSat  \
# 0  Not started career yet    Not started Job yet
# 1      Slightly satisfied     Slightly satisfied
# 2          Very satisfied     Slightly satisfied
# 3       Very dissatisfied  Slightly dissatisfied
# 4          Very satisfied     Slightly satisfied
#
#                                              JobSeek             CompFreq  \
# 0                                         Cannot say  Not yet compensated
# 1  I’m not actively looking, but I am open to new...              Monthly
# 2       I am not interested in new job opportunities               Yearly
# 3       I am not interested in new job opportunities  Not yet compensated
# 4       I am not interested in new job opportunities              Monthly
#
#    TotalComp($)  WorkWeekHrs                        WorkRemote  \
# 0           0.0          0.0                  Not started work
# 1        8820.0         40.0  Less than once per month / Never
# 2       61000.0         80.0  Less than once per month / Never
# 3           0.0         55.0             A few days each month
# 4      366420.0         15.0             A few days each month
#
#             WorkLoc                           LanguageWorkedWith  \
# 0  Not started work              HTML/CSS;Java;JavaScript;Python
# 1              Home                                     HTML/CSS
# 2              Home                          C;C++;C#;Python;SQL
# 3            Office  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 4              Home                                   Java;R;SQL
#
#                                  DatabaseWorkedWith SocialMedia  \
# 0                                            SQLite     Twitter
# 1                                        PostgreSQL      Reddit
# 2                                      MySQL;SQLite      Reddit
# 3  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite    Facebook
# 4                                MongoDB;PostgreSQL     YouTube
#
#          SO1stVisit                      SOVisitFreq  \
# 0              2017  A few times per month or weekly
# 1              2011             A few times per week
# 2              2014            Daily or almost daily
# 3  I don't remember           Multiple times per day
# 4              2011  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender
# 0  Find answers to specific questions;Learn how t...  14.0    Man
# 1  Find answers to specific questions;Learn how t...  28.0    Man
# 2  Find answers to specific questions;Pass the ti...  22.0    Man
# 3                 Find answers to specific questions  30.0    Man
# 4                 Find answers to specific questions  28.0    Man

# %%
df.shape
# Out:
# (75218, 29)

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df.describe()
# Out:
#          Respondent  TotalComp($)   WorkWeekHrs           Age
# count  75218.000000  7.521800e+04  75218.000000  75218.000000
# mean   44452.963626  8.725209e+04     32.694350     30.364692
# std    25675.295790  2.421598e+05     38.147132      9.085892
# min        1.000000  0.000000e+00      0.000000      1.000000
# 25%    22189.250000  0.000000e+00     15.000000     24.000000
# 50%    44499.500000  2.886000e+04     40.000000     29.000000
# 75%    66672.750000  7.615600e+04     40.000000     35.000000
# max    88883.000000  2.000000e+06   4850.000000     99.000000

# %% [markdown]
# ### The totalComp column has a problem which needs to be fixed

# %%
df['TotalComp($)']=df['TotalComp($)']/10

# %%
df.describe()
# Out:
#          Respondent   TotalComp($)   WorkWeekHrs           Age
# count  75218.000000   75218.000000  75218.000000  75218.000000
# mean   44452.963626    8725.209007     32.694350     30.364692
# std    25675.295790   24215.979540     38.147132      9.085892
# min        1.000000       0.000000      0.000000      1.000000
# 25%    22189.250000       0.000000     15.000000     24.000000
# 50%    44499.500000    2886.000000     40.000000     29.000000
# 75%    66672.750000    7615.600000     40.000000     35.000000
# max    88883.000000  200000.000000   4850.000000     99.000000

# %%
df.head()
# Out:
#    Respondent                                         Profession  \
# 0           1             I am a student who is learning to code
# 1           3  I am not primarily a developer, but I write co...
# 2           4                     I am a developer by profession
# 3           5                     I am a developer by profession
# 4           6  I am not primarily a developer, but I write co...
#
#                   OpenSourcer                              Employment  \
# 0                       Never  Not employed, and not looking for work
# 1                       Never                      Employed full-time
# 2                       Never                      Employed full-time
# 3  Once a month or more often                      Employed full-time
# 4                       Never                      Employed full-time
#
#           Country Student                                   EdLevel  \
# 0  United Kingdom      No                 Primary/elementary school
# 1        Thailand      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2   United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3         Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4          Canada      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                 No undergrad major
# 1                      Web development or web design
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4                          Mathematics or statistics
#
#                                    OtherNondegreeEdu  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taught yourself a new language, framework, or ...
# 2  Taken an online course in programming or softw...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                                              DevType YearsCode Age1stCode  \
# 0                                      None of these         4         10
# 1  Designer;Developer, back-end;Developer, front-...         3         22
# 2                              Developer, full-stack         3         16
# 3  Academic researcher;Developer, desktop or ente...        16         14
# 4  Data or business analyst;Data scientist or mac...        13         15
#
#                 CareerSat                 JobSat  \
# 0  Not started career yet    Not started Job yet
# 1      Slightly satisfied     Slightly satisfied
# 2          Very satisfied     Slightly satisfied
# 3       Very dissatisfied  Slightly dissatisfied
# 4          Very satisfied     Slightly satisfied
#
#                                              JobSeek             CompFreq  \
# 0                                         Cannot say  Not yet compensated
# 1  I’m not actively looking, but I am open to new...              Monthly
# 2       I am not interested in new job opportunities               Yearly
# 3       I am not interested in new job opportunities  Not yet compensated
# 4       I am not interested in new job opportunities              Monthly
#
#    TotalComp($)  WorkWeekHrs                        WorkRemote  \
# 0           0.0          0.0                  Not started work
# 1         882.0         40.0  Less than once per month / Never
# 2        6100.0         80.0  Less than once per month / Never
# 3           0.0         55.0             A few days each month
# 4       36642.0         15.0             A few days each month
#
#             WorkLoc                           LanguageWorkedWith  \
# 0  Not started work              HTML/CSS;Java;JavaScript;Python
# 1              Home                                     HTML/CSS
# 2              Home                          C;C++;C#;Python;SQL
# 3            Office  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 4              Home                                   Java;R;SQL
#
#                                  DatabaseWorkedWith SocialMedia  \
# 0                                            SQLite     Twitter
# 1                                        PostgreSQL      Reddit
# 2                                      MySQL;SQLite      Reddit
# 3  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite    Facebook
# 4                                MongoDB;PostgreSQL     YouTube
#
#          SO1stVisit                      SOVisitFreq  \
# 0              2017  A few times per month or weekly
# 1              2011             A few times per week
# 2              2014            Daily or almost daily
# 3  I don't remember           Multiple times per day
# 4              2011  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender
# 0  Find answers to specific questions;Learn how t...  14.0    Man
# 1  Find answers to specific questions;Learn how t...  28.0    Man
# 2  Find answers to specific questions;Pass the ti...  22.0    Man
# 3                 Find answers to specific questions  30.0    Man
# 4                 Find answers to specific questions  28.0    Man

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
print(df['Profession'].value_counts()/len(df['Profession']))
(df['Profession'].value_counts()/len(df['Profession'])).plot(kind='bar', figsize=(10,10))
# Out:
# I am a developer by profession                                                   0.761041
# I am a student who is learning to code                                           0.103738
# I am not primarily a developer, but I write code sometimes as part of my work    0.083703
# I code primarily as a hobby                                                      0.032519
# I used to be a developer by profession, but no longer am                         0.016299
# Not Sure What i am                                                               0.002699
# Name: Profession, dtype: float64

# %% [markdown]
# #### About 76% of SO developers actually are developers by profession which is of no suprise, the students who are learning how to code form the second largest group on SO which is impressive, showing they are wiling to learn

# %%
df['EdLevel'].value_counts()/len(df['EdLevel'])
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              0.447167
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           0.221423
# Some college/university study without earning a degree                                0.122457
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.096958
# Associate degree                                                                      0.033037
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             0.027002
# Cannot Say                                                                            0.019836
# Primary/elementary school                                                             0.014491
# Professional degree (JD, MD, etc.)                                                    0.013228
# I never completed any formal education                                                0.004401
# Name: EdLevel, dtype: float64

# %% [markdown]
# #### Individuals with bachelors degree accounted for almost 45% and its clear that just a few people have PhD's, only about 2%.

# %%
df.groupby('EdLevel')['TotalComp($)'].mean()
# Out:
# EdLevel
# Associate degree                                                                      10215.157022
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              10092.511863
# Cannot Say                                                                             5017.310389
# I never completed any formal education                                                 8287.580665
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            9147.527145
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             13066.694141
# Primary/elementary school                                                              2176.692294
# Professional degree (JD, MD, etc.)                                                     5358.283216
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     3075.564884
# Some college/university study without earning a degree                                 7837.667094
# Name: TotalComp($), dtype: float64

# %%
ax=(df.groupby('EdLevel')['TotalComp($)'].mean().sort_values(ascending=False)).plot(kind='bar', figsize=(9,9))
ax.set_title('Average Salaries of Individuals per Education level',fontdict={'size':20});

# %% [markdown]
# ####  Here, it can be seen that individuals with PhD tend to earn the most, which makes sense, the higher your educational level, the bigger the pay. Its clear that with even a bachelors, you can make a good amount of money, around 13K dollars per month as a developer. Its not a requirement to have a degree to earn good money, as individuals who have no formal degree and are self taught make around 8K dollars monthly.

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                    OtherNondegreeEdu        DevType YearsCode  \
# 0  Taught yourself a new language, framework, or ...  None of these         4
#
#   Age1stCode               CareerSat               JobSat     JobSeek  \
# 0         10  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender
# 0  Find answers to specific questions;Learn how t...  14.0    Man

# %%
df['Student'].value_counts()/len(df['Student'])
# Out:
# No                     0.762025
# Yes, full-time         0.166689
# Yes, part-time         0.060823
# I prefer not to say    0.010463
# Name: Student, dtype: float64

# %%
(df['Student'].value_counts()).plot(kind='pie', figsize=(10,10))

# %% [markdown]
# ##### most people were not students, with about 76% of them not being students, even those that were students, only 16% were full time, meaning they were now learning to become developers

# %%
df['Country'].value_counts()/len(df['Country'])
# Out:
# United States                            0.241604
# India                                    0.090537
# United Kingdom                           0.067497
# Germany                                  0.067311
# Canada                                   0.039060
#                                            ...
# Belize                                   0.000013
# North Korea                              0.000013
# Papua New Guinea                         0.000013
# Dominica                                 0.000013
# Democratic People's Republic of Korea    0.000013
# Name: Country, Length: 174, dtype: float64

# %% [markdown]
# #### Well before even starting my analysis, i knew USA would be the country with most people, they account for 24% and the rest dont even get up to 1% of people in this study.

# %% [markdown]
# ##### Have to consider only individuals who are paid, so everyone who doesnt have a job or hasnt started working would be removed from the analysis

# %%
with_salary=df[df['TotalComp($)']>1]

# %%
with_salary.groupby('Country')['TotalComp($)'].mean()
# Out:
# Country
# Afghanistan                              2553.600000
# Albania                                  2243.636170
# Algeria                                  4054.674286
# Andorra                                 17186.200000
# Angola                                    776.400000
#                                             ...
# Venezuela, Bolivarian Republic of...     1524.189189
# Viet Nam                                 1769.275641
# Yemen                                    1690.916667
# Zambia                                   1007.537500
# Zimbabwe                                 3642.307692
# Name: TotalComp($), Length: 158, dtype: float64

# %%
with_sal_per_country=pd.DataFrame(with_salary.groupby('Country')['TotalComp($)'].mean()).sort_values(by='TotalComp($)', ascending=False)[:20]

# %%
ax=(pd.DataFrame(with_salary.groupby('Country')['TotalComp($)'].mean()).sort_values(by='TotalComp($)', ascending=False)[:20]).plot(kind='bar', figsize=(20,20))
ax.set_title('Top 20 Average Salaries of Individuals in Different Countries ',fontdict={'size':20});

# %%
with_sal_per_country['TotalComp($)'].mean()
# Out:
# 21876.49586772944

# %% [markdown]
# #### Well well, individuals from Liechtensein are paid the most averagely of all countries captured in this data with a monthly salary of aroumd 80K. Maybe we all need to move there as developers, haha.Generally, the monthly salary per country seems to be good, with an average of over 14.6K dollars per month

# %%
df['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                         7368
# None of these                                                                                                                                                                                                                                                                                                                                                                 5066
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                           4183
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                                                                                                2123
# Developer, front-end                                                                                                                                                                                                                                                                                                                                                          1878
#                                                                                                                                                                                                                                                                                                                                                                               ...
# Academic researcher;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;Educator;Engineer, data;Engineer, site reliability;Scientist;Student;System administrator       1
# Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Educator;Scientist;Student                                                                                                                                                                      1
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Educator;Engineering manager;Marketing or sales professional;Product manager;Senior executive/VP                                                                                                                                                                                           1
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Marketing or sales professional;Product manager;Senior executive/VP;System administrator                                                                                                                                                                                                   1
# Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Developer, back-end;Educator;Product manager;Scientist                                                                                                                                                                                                                                1
# Name: DevType, Length: 11771, dtype: int64

# %%
df['primary_dev_type']=df['DevType'].str.split(';', expand=True)[0]
df['primary_dev_type']
# Out:
# 0                   None of these
# 1                        Designer
# 2           Developer, full-stack
# 3             Academic researcher
# 4        Data or business analyst
#                    ...
# 75213               None of these
# 75214               None of these
# 75215                     Student
# 75216         Academic researcher
# 75217               None of these
# Name: primary_dev_type, Length: 75218, dtype: object

# %%
df['secondary_dev_type']=df['DevType'].str.split(';', expand=True)[1]
df['secondary_dev_type']
# Out:
# 0                                                 None
# 1                                  Developer, back-end
# 2                                                 None
# 3        Developer, desktop or enterprise applications
# 4        Data scientist or machine learning specialist
#                              ...
# 75213                                             None
# 75214                                             None
# 75215                                             None
# 75216                                         Designer
# 75217                                             None
# Name: secondary_dev_type, Length: 75218, dtype: object

# %%
df['tertiary_dev_type']=df['DevType'].str.split(';', expand=True)[2]
df['tertiary_dev_type']
# Out:
# 0                               None
# 1               Developer, front-end
# 2                               None
# 3              Developer, full-stack
# 4             Database administrator
#                     ...
# 75213                           None
# 75214                           None
# 75215                           None
# 75216    Developer, game or graphics
# 75217                           None
# Name: tertiary_dev_type, Length: 75218, dtype: object

# %%
df['extra_dev_type']=df['DevType'].str.split(';', expand=True)[3]
df['extra_dev_type']
# Out:
# 0                         None
# 1        Developer, full-stack
# 2                         None
# 3            Developer, mobile
# 4               Engineer, data
#                  ...
# 75213                     None
# 75214                     None
# 75215                     None
# 75216                Scientist
# 75217                     None
# Name: extra_dev_type, Length: 75218, dtype: object

# %%
df.head(5)
# Out:
#    Respondent                                         Profession  \
# 0           1             I am a student who is learning to code
# 1           3  I am not primarily a developer, but I write co...
# 2           4                     I am a developer by profession
# 3           5                     I am a developer by profession
# 4           6  I am not primarily a developer, but I write co...
#
#                   OpenSourcer                              Employment  \
# 0                       Never  Not employed, and not looking for work
# 1                       Never                      Employed full-time
# 2                       Never                      Employed full-time
# 3  Once a month or more often                      Employed full-time
# 4                       Never                      Employed full-time
#
#           Country Student                                   EdLevel  \
# 0  United Kingdom      No                 Primary/elementary school
# 1        Thailand      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2   United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3         Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4          Canada      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                 No undergrad major
# 1                      Web development or web design
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4                          Mathematics or statistics
#
#                                    OtherNondegreeEdu  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taught yourself a new language, framework, or ...
# 2  Taken an online course in programming or softw...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                                              DevType YearsCode Age1stCode  \
# 0                                      None of these         4         10
# 1  Designer;Developer, back-end;Developer, front-...         3         22
# 2                              Developer, full-stack         3         16
# 3  Academic researcher;Developer, desktop or ente...        16         14
# 4  Data or business analyst;Data scientist or mac...        13         15
#
#                 CareerSat                 JobSat  \
# 0  Not started career yet    Not started Job yet
# 1      Slightly satisfied     Slightly satisfied
# 2          Very satisfied     Slightly satisfied
# 3       Very dissatisfied  Slightly dissatisfied
# 4          Very satisfied     Slightly satisfied
#
#                                              JobSeek             CompFreq  \
# 0                                         Cannot say  Not yet compensated
# 1  I’m not actively looking, but I am open to new...              Monthly
# 2       I am not interested in new job opportunities               Yearly
# 3       I am not interested in new job opportunities  Not yet compensated
# 4       I am not interested in new job opportunities              Monthly
#
#    TotalComp($)  WorkWeekHrs                        WorkRemote  \
# 0           0.0          0.0                  Not started work
# 1         882.0         40.0  Less than once per month / Never
# 2        6100.0         80.0  Less than once per month / Never
# 3           0.0         55.0             A few days each month
# 4       36642.0         15.0             A few days each month
#
#             WorkLoc                           LanguageWorkedWith  \
# 0  Not started work              HTML/CSS;Java;JavaScript;Python
# 1              Home                                     HTML/CSS
# 2              Home                          C;C++;C#;Python;SQL
# 3            Office  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 4              Home                                   Java;R;SQL
#
#                                  DatabaseWorkedWith SocialMedia  \
# 0                                            SQLite     Twitter
# 1                                        PostgreSQL      Reddit
# 2                                      MySQL;SQLite      Reddit
# 3  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite    Facebook
# 4                                MongoDB;PostgreSQL     YouTube
#
#          SO1stVisit                      SOVisitFreq  \
# 0              2017  A few times per month or weekly
# 1              2011             A few times per week
# 2              2014            Daily or almost daily
# 3  I don't remember           Multiple times per day
# 4              2011  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
# 1  Find answers to specific questions;Learn how t...  28.0    Man
# 2  Find answers to specific questions;Pass the ti...  22.0    Man
# 3                 Find answers to specific questions  30.0    Man
# 4                 Find answers to specific questions  28.0    Man
#
#            primary_dev_type                             secondary_dev_type  \
# 0             None of these                                           None
# 1                  Designer                            Developer, back-end
# 2     Developer, full-stack                                           None
# 3       Academic researcher  Developer, desktop or enterprise applications
# 4  Data or business analyst  Data scientist or machine learning specialist
#
#         tertiary_dev_type         extra_dev_type
# 0                    None                   None
# 1    Developer, front-end  Developer, full-stack
# 2                    None                   None
# 3   Developer, full-stack      Developer, mobile
# 4  Database administrator         Engineer, data

# %%
df=df.drop(columns=['DevType'])

# %%
primary_dev_salary=pd.DataFrame(df.groupby('primary_dev_type')['TotalComp($)'].mean()).sort_values(by='TotalComp($)', ascending=False)

# %%
ax=(pd.DataFrame(df.groupby('primary_dev_type')['TotalComp($)'].mean()).sort_values(by='TotalComp($)', ascending=False)).plot(kind='bar', figsize=(20,20))
ax.set_title('Average Salaries of the different types of Developers',fontdict={'size':20});

# %% [markdown]
# ### Well, the senior executives/ vice president of companies are the most paid developers with monthly salary of around 16K. My interest is on data science adn machine learning and they are paid around 13K dollars monthly, which is a very good salary. Not suprisngly, the students are paid the least, with most of them doing internships so they are paid very little to learn

# %%
(pd.DataFrame(df.groupby(['primary_dev_type','secondary_dev_type','tertiary_dev_type'])['TotalComp($)'].mean()))
# Out:
#                                                                                                         TotalComp($)
# primary_dev_type                secondary_dev_type       tertiary_dev_type
# Academic researcher             Data or business analyst Data scientist or machine learning specialist   6228.161419
#                                                          Database administrator                          7103.950735
#                                                          Designer                                        7237.712903
#                                                          DevOps specialist                               1165.200000
#                                                          Developer, QA or test                           2511.600000
# ...                                                                                                              ...
# Marketing or sales professional Product manager          Senior executive/VP                                0.000000
#                                                          Student                                            0.000000
# Product manager                 Senior executive/VP      System administrator                            4869.450000
#                                 Student                  System administrator                            1416.000000
# Scientist                       Student                  System administrator                            1325.400000
#
# [1190 rows x 1 columns]

# %%
primary_data_science=df[df['primary_dev_type']=='Data scientist or machine learning specialist']
(primary_data_science.groupby(['primary_dev_type','secondary_dev_type','tertiary_dev_type'])['TotalComp($)'].mean().sort_values(ascending=False)[:20]).plot(kind='bar', figsize=(18,18))

# %% [markdown]
# ### Considering only those individuals whose primary focus was on data science and machine learning, i looked at the average salaries when they have other job descriptions aside the data science, it seems those who were also developers and dealt with embedded applications had the highest average salary of around 130K dollars.

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                                    OtherNondegreeEdu YearsCode Age1stCode  \
# 0  Taught yourself a new language, framework, or ...         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type
# 0    None of these               None              None           None

# %%
df['WorkRemote'].value_counts()/len(df['WorkRemote'])
# Out:
# Less than once per month / Never                           0.355221
# A few days each month                                      0.204260
# Not started work                                           0.178335
# All or almost all the time (I'm full-time remote)          0.098886
# Less than half the time, but at least one day each week    0.075128
# It's complicated                                           0.038847
# More than half, but not all, the time                      0.026908
# About half the time                                        0.022415
# Name: WorkRemote, dtype: float64

# %% [markdown]
# ##### Hmm... seems most people dont work really work remotely, which is a bit suprising to me. This data is from 2019, i am sure the number would greatly increase in 2020 due to the corona virus and more and more people having to work remotely. I have a keen interest in remote work since its my current target

# %%
df['OtherNondegreeEdu']=df['OtherNondegreeEdu'].str.split(',', expand=True)[0]

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor  \
# 0  Primary/elementary school  No undergrad major
#
#                 OtherNondegreeEdu YearsCode Age1stCode  \
# 0  Taught yourself a new language         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type
# 0    None of these               None              None           None

# %%
df['OtherNondegreeEdu'].value_counts()
# Out:
# Taken an online course in programming or software development (e.g. a MOOC);Taught yourself a new language                                                                                                                                                                                                13114
# Taught yourself a new language                                                                                                                                                                                                                                                                            13046
# Taken an online course in programming or software development (e.g. a MOOC);Received on-the-job training in software development;Taught yourself a new language                                                                                                                                            8172
# Received on-the-job training in software development;Taught yourself a new language                                                                                                                                                                                                                        6229
# Didnt take other educational route                                                                                                                                                                                                                                                                         2633
#                                                                                                                                                                                                                                                                                                           ...
# Participated in a full-time developer training program or bootcamp;Taken a part-time in-person course in programming or software development;Completed an industry certification program (e.g. MCPD);Participated in a hackathon;Contributed to open source software                                          1
# Participated in a full-time developer training program or bootcamp;Completed an industry certification program (e.g. MCPD);Received on-the-job training in software development;Participated in online coding competitions (e.g. HackerRank                                                                   1
# Taken an online course in programming or software development (e.g. a MOOC);Participated in a full-time developer training program or bootcamp;Completed an industry certification program (e.g. MCPD);Participated in a hackathon;Contributed to open source software                                        1
# Taken a part-time in-person course in programming or software development;Completed an industry certification program (e.g. MCPD);Received on-the-job training in software development;Participated in a hackathon                                                                                            1
# Taken an online course in programming or software development (e.g. a MOOC);Taken a part-time in-person course in programming or software development;Completed an industry certification program (e.g. MCPD);Received on-the-job training in software development;Contributed to open source software        1
# Name: OtherNondegreeEdu, Length: 187, dtype: int64

# %%
df['OtherPrimaryEdu']=df['OtherNondegreeEdu'].str.split(';', expand=True)[0]
df['OtherSecondaryEdu']=df['OtherNondegreeEdu'].str.split(';', expand=True)[1]
df['OthertertiaryEdu']=df['OtherNondegreeEdu'].str.split(';', expand=True)[2]

# %%
df.head(5)
# Out:
#    Respondent                                         Profession  \
# 0           1             I am a student who is learning to code
# 1           3  I am not primarily a developer, but I write co...
# 2           4                     I am a developer by profession
# 3           5                     I am a developer by profession
# 4           6  I am not primarily a developer, but I write co...
#
#                   OpenSourcer                              Employment  \
# 0                       Never  Not employed, and not looking for work
# 1                       Never                      Employed full-time
# 2                       Never                      Employed full-time
# 3  Once a month or more often                      Employed full-time
# 4                       Never                      Employed full-time
#
#           Country Student                                   EdLevel  \
# 0  United Kingdom      No                 Primary/elementary school
# 1        Thailand      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2   United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3         Ukraine      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4          Canada      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                 No undergrad major
# 1                      Web development or web design
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4                          Mathematics or statistics
#
#                                    OtherNondegreeEdu YearsCode Age1stCode  \
# 0                     Taught yourself a new language         4         10
# 1                     Taught yourself a new language         3         22
# 2  Taken an online course in programming or softw...         3         16
# 3  Taken an online course in programming or softw...        16         14
# 4  Taken an online course in programming or softw...        13         15
#
#                 CareerSat                 JobSat  \
# 0  Not started career yet    Not started Job yet
# 1      Slightly satisfied     Slightly satisfied
# 2          Very satisfied     Slightly satisfied
# 3       Very dissatisfied  Slightly dissatisfied
# 4          Very satisfied     Slightly satisfied
#
#                                              JobSeek             CompFreq  \
# 0                                         Cannot say  Not yet compensated
# 1  I’m not actively looking, but I am open to new...              Monthly
# 2       I am not interested in new job opportunities               Yearly
# 3       I am not interested in new job opportunities  Not yet compensated
# 4       I am not interested in new job opportunities              Monthly
#
#    TotalComp($)  WorkWeekHrs                        WorkRemote  \
# 0           0.0          0.0                  Not started work
# 1         882.0         40.0  Less than once per month / Never
# 2        6100.0         80.0  Less than once per month / Never
# 3           0.0         55.0             A few days each month
# 4       36642.0         15.0             A few days each month
#
#             WorkLoc                           LanguageWorkedWith  \
# 0  Not started work              HTML/CSS;Java;JavaScript;Python
# 1              Home                                     HTML/CSS
# 2              Home                          C;C++;C#;Python;SQL
# 3            Office  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 4              Home                                   Java;R;SQL
#
#                                  DatabaseWorkedWith SocialMedia  \
# 0                                            SQLite     Twitter
# 1                                        PostgreSQL      Reddit
# 2                                      MySQL;SQLite      Reddit
# 3  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite    Facebook
# 4                                MongoDB;PostgreSQL     YouTube
#
#          SO1stVisit                      SOVisitFreq  \
# 0              2017  A few times per month or weekly
# 1              2011             A few times per week
# 2              2014            Daily or almost daily
# 3  I don't remember           Multiple times per day
# 4              2011  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
# 1  Find answers to specific questions;Learn how t...  28.0    Man
# 2  Find answers to specific questions;Pass the ti...  22.0    Man
# 3                 Find answers to specific questions  30.0    Man
# 4                 Find answers to specific questions  28.0    Man
#
#            primary_dev_type                             secondary_dev_type  \
# 0             None of these                                           None
# 1                  Designer                            Developer, back-end
# 2     Developer, full-stack                                           None
# 3       Academic researcher  Developer, desktop or enterprise applications
# 4  Data or business analyst  Data scientist or machine learning specialist
#
#         tertiary_dev_type         extra_dev_type  \
# 0                    None                   None
# 1    Developer, front-end  Developer, full-stack
# 2                    None                   None
# 3   Developer, full-stack      Developer, mobile
# 4  Database administrator         Engineer, data
#
#                                      OtherPrimaryEdu  \
# 0                     Taught yourself a new language
# 1                     Taught yourself a new language
# 2  Taken an online course in programming or softw...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                                    OtherSecondaryEdu  \
# 0                                               None
# 1                                               None
# 2  Received on-the-job training in software devel...
# 3  Received on-the-job training in software devel...
# 4  Received on-the-job training in software devel...
#
#                  OthertertiaryEdu
# 0                            None
# 1                            None
# 2  Taught yourself a new language
# 3  Taught yourself a new language
# 4  Taught yourself a new language

# %%
df=df.drop(columns=['OtherNondegreeEdu'])

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu
# 0  Taught yourself a new language              None             None

# %%
df['OtherPrimaryEdu'].value_counts()/len(df['OtherPrimaryEdu'])
# Out:
# Taken an online course in programming or software development (e.g. a MOOC)    0.585152
# Taught yourself a new language                                                 0.173443
# Received on-the-job training in software development                           0.092092
# Participated in a full-time developer training program or bootcamp             0.037132
# Taken a part-time in-person course in programming or software development      0.036361
# Didnt take other educational route                                             0.035005
# Completed an industry certification program (e.g. MCPD)                        0.028211
# Contributed to open source software                                            0.005517
# Participated in online coding competitions (e.g. HackerRank                    0.003669
# Participated in a hackathon                                                    0.003417
# Name: OtherPrimaryEdu, dtype: float64

# %% [markdown]
# #### As i expected most people got their alternative education from online courses, almost 60% of them. Nowadays, thats how most people learn to people developers.

# %%
df.groupby('OtherPrimaryEdu')['TotalComp($)'].mean()
# Out:
# OtherPrimaryEdu
# Completed an industry certification program (e.g. MCPD)                        11189.698492
# Contributed to open source software                                             7048.444337
# Didnt take other educational route                                              4963.177554
# Participated in a full-time developer training program or bootcamp              8447.868385
# Participated in a hackathon                                                     6674.271595
# Participated in online coding competitions (e.g. HackerRank                     4521.470652
# Received on-the-job training in software development                           11100.488870
# Taken a part-time in-person course in programming or software development       8546.808592
# Taken an online course in programming or software development (e.g. a MOOC)     8577.661549
# Taught yourself a new language                                                  8599.660172
# Name: TotalComp($), dtype: float64

# %%
ax=df.groupby('OtherPrimaryEdu')['TotalComp($)'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(15,10));

# %% [markdown]
# #### Well, looks like individuals who received the education from industries like on the job trainings tend to earn higher averagely. These individuals very likely had jobs before and just furthered their education through company sponsored education.
# #### Where the majority of people fall, that is the online courses, get on average around 8.5K dollars

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu
# 0  Taught yourself a new language              None             None

# %%
primary_other_edu=df[df['OtherPrimaryEdu']=='Taken an online course in programming or software development (e.g. a MOOC)']
(primary_other_edu.groupby(['OtherPrimaryEdu','OtherSecondaryEdu','OthertertiaryEdu'])['TotalComp($)'].mean().sort_values(ascending=False)).plot(kind='bar', figsize=(20,20))

# %% [markdown]
# #### Well that was a long list, individuals who took online courses, completed an industry certification and participated in a hackathon in that order, averagely earned higher among all individuals who took an online course as a primary  alternative education, earning almost 140K

# %%
primary_other_edu.head()
# Out:
#    Respondent                                         Profession  \
# 2           4                     I am a developer by profession
# 3           5                     I am a developer by profession
# 4           6  I am not primarily a developer, but I write co...
# 7           9                     I am a developer by profession
# 9          12             I am a student who is learning to code
#
#                   OpenSourcer          Employment        Country  \
# 2                       Never  Employed full-time  United States
# 3  Once a month or more often  Employed full-time        Ukraine
# 4                       Never  Employed full-time         Canada
# 7  Once a month or more often  Employed full-time    New Zealand
# 9                       Never  Employed part-time         Canada
#
#           Student                                            EdLevel  \
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7              No  Some college/university study without earning ...
# 9  Yes, full-time  Some college/university study without earning ...
#
#                                       UndergradMajor YearsCode Age1stCode  \
# 2  Computer science, computer engineering, or sof...         3         16
# 3  Computer science, computer engineering, or sof...        16         14
# 4                          Mathematics or statistics        13         15
# 7  Computer science, computer engineering, or sof...        12         11
# 9                          Mathematics or statistics         5         16
#
#                 CareerSat                 JobSat  \
# 2          Very satisfied     Slightly satisfied
# 3       Very dissatisfied  Slightly dissatisfied
# 4          Very satisfied     Slightly satisfied
# 7      Slightly satisfied     Slightly satisfied
# 9  Not started career yet    Not started Job yet
#
#                                              JobSeek             CompFreq  \
# 2       I am not interested in new job opportunities               Yearly
# 3       I am not interested in new job opportunities  Not yet compensated
# 4       I am not interested in new job opportunities              Monthly
# 7  I’m not actively looking, but I am open to new...               Yearly
# 9       I am not interested in new job opportunities  Not yet compensated
#
#    TotalComp($)  WorkWeekHrs                        WorkRemote  \
# 2        6100.0         80.0  Less than once per month / Never
# 3           0.0         55.0             A few days each month
# 4       36642.0         15.0             A few days each month
# 7        9517.9         32.0  Less than once per month / Never
# 9           0.0          0.0                  Not started work
#
#             WorkLoc                                 LanguageWorkedWith  \
# 2              Home                                C;C++;C#;Python;SQL
# 3            Office        C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 4              Home                                         Java;R;SQL
# 7            Office  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9  Not started work   Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
#
#                                  DatabaseWorkedWith SocialMedia  \
# 2                                      MySQL;SQLite      Reddit
# 3  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite    Facebook
# 4                                MongoDB;PostgreSQL     YouTube
# 7                        DynamoDB;PostgreSQL;SQLite     Twitter
# 9                           MySQL;PostgreSQL;SQLite      Reddit
#
#          SO1stVisit                      SOVisitFreq  \
# 2              2014            Daily or almost daily
# 3  I don't remember           Multiple times per day
# 4              2011  A few times per month or weekly
# 7              2013            Daily or almost daily
# 9              2014  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 2  Find answers to specific questions;Pass the ti...  22.0    Man
# 3                 Find answers to specific questions  30.0    Man
# 4                 Find answers to specific questions  28.0    Man
# 7  Find answers to specific questions;Contribute ...  23.0    Man
# 9  Find answers to specific questions;Learn how t...  21.0  Woman
#
#            primary_dev_type                             secondary_dev_type  \
# 2     Developer, full-stack                                           None
# 3       Academic researcher  Developer, desktop or enterprise applications
# 4  Data or business analyst  Data scientist or machine learning specialist
# 7    Database administrator                            Developer, back-end
# 9  Data or business analyst  Data scientist or machine learning specialist
#
#         tertiary_dev_type         extra_dev_type  \
# 2                    None                   None
# 3   Developer, full-stack      Developer, mobile
# 4  Database administrator         Engineer, data
# 7    Developer, front-end  Developer, full-stack
# 9          Engineer, data                Student
#
#                                      OtherPrimaryEdu  \
# 2  Taken an online course in programming or softw...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
# 7  Taken an online course in programming or softw...
# 9  Taken an online course in programming or softw...
#
#                                    OtherSecondaryEdu  \
# 2  Received on-the-job training in software devel...
# 3  Received on-the-job training in software devel...
# 4  Received on-the-job training in software devel...
# 7  Participated in a full-time developer training...
# 9                     Taught yourself a new language
#
#                                     OthertertiaryEdu
# 2                     Taught yourself a new language
# 3                     Taught yourself a new language
# 4                     Taught yourself a new language
# 7  Taken a part-time in-person course in programm...
# 9                                               None

# %%
plt.figure(figsize=(10,8))
df['Age'].hist()

# %% [markdown]
# #### Regarding the age distribution, its a bit right skewed with most people around the ages of 20 and 30

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu
# 0  Taught yourself a new language              None             None

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            68206
# Woman                                                           5227
# Prefer not to say                                                932
# Non-binary, genderqueer, or gender non-conforming                462
# Man;Non-binary, genderqueer, or gender non-conforming            150
# Woman;Non-binary, genderqueer, or gender non-conforming          135
# Woman;Man                                                         66
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       40
# Name: Gender, dtype: int64

# %%
df['Gender']=df['Gender'].str.split(',', expand=True)[0]

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu
# 0  Taught yourself a new language              None             None

# %%
df['Gender']=df['Gender'].str.split(';', expand=True)[0]

# %%
df['Gender'].value_counts()/len(df['Gender'])
# Out:
# Man                  0.908772
# Woman                0.072695
# Prefer not to say    0.012391
# Non-binary           0.006142
# Name: Gender, dtype: float64

# %%
(df['Gender'].value_counts()/len(df['Gender'])).plot(kind='pie', figsize=(10,10))

# %% [markdown]
# ### Most developers seem to be men which was expected, though a lot of womenare getting into the industry, so the gap would be closing as time goes by

# %%
df['SOVisitFreq'].value_counts()/len(df['SOVisitFreq'])
# Out:
# Multiple times per day                 0.310817
# Daily or almost daily                  0.310351
# A few times per week                   0.228589
# A few times per month or weekly        0.121912
# Less than once per month or monthly    0.028331
# Name: SOVisitFreq, dtype: float64

# %% [markdown]
# #### well seems most people actually use stack overflow, its the go to sites for most people, it is also the go to site for me

# %%
df['SO1stVisit'].value_counts()/len(df['SO1stVisit'])
# Out:
# 2010                0.122218
# I don't remember    0.114255
# 2008                0.112739
# 2012                0.102289
# 2011                0.079369
# 2013                0.077840
# 2009                0.076192
# 2014                0.076139
# 2015                0.065942
# 2016                0.053551
# 2017                0.040509
# Cannot say          0.038967
# 2018                0.025712
# 2019                0.014278
# Name: SO1stVisit, dtype: float64

# %% [markdown]
# #### Well seems most people have been using stack overflow for over 10 years, which also signifies most people have been coding for 10 years

# %%
df['SocialMedia'].value_counts()/len(df['SocialMedia'])
# Out:
# Reddit                      0.171754
# YouTube                     0.152796
# Facebook                    0.150802
# WhatsApp                    0.150616
# Twitter                     0.132854
# Instagram                   0.071871
# I don't use social media    0.057978
# LinkedIn                    0.048645
# Other                       0.041719
# Snapchat                    0.007246
# VK ВКонта́кте               0.006820
# WeChat 微信                   0.006169
# Weibo 新浪微博                  0.000558
# Youku Tudou 优酷              0.000120
# Hello                       0.000053
# Name: SocialMedia, dtype: float64

# %%
(df['SocialMedia'].value_counts()/len(df['SocialMedia'])).plot(kind='bar', figsize=(12,8));
# Out:
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 24494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 28010 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 21338 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20248 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 37239 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 24494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 28010 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 21338 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20248 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ampad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 37239 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### most people use reddit as their go to social media site, with youtube a close second. Most people use youtube to learn and follow live codings so it makes sense that its the second highest most used social media site

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc               LanguageWorkedWith DatabaseWorkedWith  \
# 0  Not started work  HTML/CSS;Java;JavaScript;Python             SQLite
#
#   SocialMedia SO1stVisit                      SOVisitFreq  \
# 0     Twitter       2017  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu
# 0  Taught yourself a new language              None             None

# %%
df['primarylanguage']=df['LanguageWorkedWith'].str.split(';', expand=True)[0]
df['secondarylanguage']=df['LanguageWorkedWith'].str.split(';', expand=True)[1]
df['thirdlanguage']=df['LanguageWorkedWith'].str.split(';', expand=True)[2]

# %%
df=df.drop(columns=['LanguageWorkedWith'])

# %%
df.head(1)
# Out:
#    Respondent                              Profession OpenSourcer  \
# 0           1  I am a student who is learning to code       Never
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel      UndergradMajor YearsCode Age1stCode  \
# 0  Primary/elementary school  No undergrad major         4         10
#
#                 CareerSat               JobSat     JobSeek  \
# 0  Not started career yet  Not started Job yet  Cannot say
#
#               CompFreq  TotalComp($)  WorkWeekHrs        WorkRemote  \
# 0  Not yet compensated           0.0          0.0  Not started work
#
#             WorkLoc DatabaseWorkedWith SocialMedia SO1stVisit  \
# 0  Not started work             SQLite     Twitter       2017
#
#                        SOVisitFreq  \
# 0  A few times per month or weekly
#
#                                            SOVisitTo   Age Gender  \
# 0  Find answers to specific questions;Learn how t...  14.0    Man
#
#   primary_dev_type secondary_dev_type tertiary_dev_type extra_dev_type  \
# 0    None of these               None              None           None
#
#                   OtherPrimaryEdu OtherSecondaryEdu OthertertiaryEdu  \
# 0  Taught yourself a new language              None             None
#
#   primarylanguage secondarylanguage thirdlanguage
# 0        HTML/CSS              Java    JavaScript

# %%
df['primarylanguage'].value_counts()/len(df['primarylanguage'])
# Out:
# Bash/Shell/PowerShell    0.335611
# HTML/CSS                 0.176952
# C#                       0.141097
# C                        0.079409
# Assembly                 0.062339
# C++                      0.055798
# Java                     0.053870
# JavaScript               0.021737
# Python                   0.019982
# Go                       0.016725
# Dart                     0.005424
# Objective-C              0.004773
# Elixir                   0.004214
# Clojure                  0.003709
# R                        0.003071
# SQL                      0.002991
# PHP                      0.002912
# Swift                    0.002353
# Other(s):                0.001888
# Ruby                     0.001423
# Kotlin                   0.001064
# VBA                      0.000731
# Scala                    0.000665
# Erlang                   0.000452
# F#                       0.000386
# Rust                     0.000213
# TypeScript               0.000186
# WebAssembly              0.000027
# Name: primarylanguage, dtype: float64

# %% [markdown]
# #### Suprisingly, tht primary language of most developers is shell with about 33% of them using that language. Suprisingly, only 1% of them used python as a primary language

# %%
primary_other_edu=df[df['primarylanguage']=='Python']
(primary_other_edu.groupby(['primarylanguage','secondarylanguage','thirdlanguage'])['TotalComp($)'].mean().sort_values(ascending=False)).plot(kind='bar', figsize=(20,20))

# %% [markdown]
# ##### My interest is on python, and most people who use python as a primary language, use scala and typescript as a secondary and third language, and they earn on average almost 90K dollars

# %%
data_ML=df[df['primary_dev_type']=='Data scientist or machine learning specialist']
data_ML.head(1)
# Out:
#      Respondent                      Profession  \
# 124         146  I am a developer by profession
#
#                                            OpenSourcer          Employment  \
# 124  Less than once a month but more than once per ...  Employed full-time
#
#            Country Student                                            EdLevel  \
# 124  United States      No  Some college/university study without earning ...
#
#                                         UndergradMajor YearsCode Age1stCode  \
# 124  Computer science, computer engineering, or sof...        35         12
#
#               CareerSat              JobSat  \
# 124  Slightly satisfied  Slightly satisfied
#
#                                                JobSeek             CompFreq  \
# 124  I’m not actively looking, but I am open to new...  Not yet compensated
#
#      TotalComp($)  WorkWeekHrs  \
# 124           0.0         55.0
#
#                                             WorkRemote WorkLoc  \
# 124  Less than half the time, but at least one day ...    Home
#
#     DatabaseWorkedWith SocialMedia        SO1stVisit           SOVisitFreq  \
# 124      MongoDB;Redis      Reddit  I don't remember  A few times per week
#
#                               SOVisitTo   Age Gender  \
# 124  Find answers to specific questions  47.0    Man
#
#                                   primary_dev_type   secondary_dev_type  \
# 124  Data scientist or machine learning specialist  Developer, back-end
#
#     tertiary_dev_type extra_dev_type                 OtherPrimaryEdu  \
# 124              None           None  Taught yourself a new language
#
#     OtherSecondaryEdu OthertertiaryEdu        primarylanguage  \
# 124              None             None  Bash/Shell/PowerShell
#
#     secondarylanguage thirdlanguage
# 124                 C        Python

# %%
data_ML.groupby('primarylanguage')['TotalComp($)'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(15,10))

# %% [markdown]
# #### Most people who are data scientists or ML engineers use F# as a primary language. The individuals who used python as a primary language earned almost 12K. Its suprising because i thought python was the go to language for data science

# %%
df.corr()
# Out:
#               Respondent  TotalComp($)  WorkWeekHrs       Age
# Respondent      1.000000      0.003004    -0.002680 -0.001775
# TotalComp($)    0.003004      1.000000     0.095440  0.119535
# WorkWeekHrs    -0.002680      0.095440     1.000000  0.123888
# Age            -0.001775      0.119535     0.123888  1.000000

# %% [markdown]
# #### There isnt much correlation among the numerical features, the highest correlation observed was age and workweekhrs, with a positive correlation. It could mean that the older you are, the more you work longer hours. This could be due to the older people having bigger jobs and hence more responsibilites at the job
# #### Another positive correlation is age and total compensation, the older you are, the more you are paid. Well, as seen previously, the older individuals tend to have the bigger jobs, more experience and hence the better pay.

# %% [markdown]
# # Many findings were obtained here, some very suprising and most quite obvious. Any one can look at the graphs and tables to find what they needed from the 2019 stackoverflow survey.
